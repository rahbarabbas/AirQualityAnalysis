# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-v0_8')

# %%
import os
if os.path.exists('datasets'):
    print(os.listdir('datasets'))
# Out:
# ['site_272.csv', 'site_277.csv', 'site_297.csv', 'site_5128.csv', 'site_5460.csv', 'site_5462.csv']

# %%
pd.set_option('display.max_columns',None)

# %%
df1 = pd.read_csv('datasets/site_272.csv',index_col=0, parse_dates=['From Date','To Date'])
df1.head(3)
# Out:
#             From Date             To Date  PM2.5 (ug/m3)  PM10 (ug/m3)  \
# 0 2018-01-01 00:00:00 2018-01-01 01:00:00         148.77           NaN
# 1 2018-01-01 01:00:00 2018-01-01 02:00:00         130.14           NaN
# 2 2018-01-01 02:00:00 2018-01-01 03:00:00         123.00           NaN
#
#    AT (degree C)  SR (W/mt2)  RH (%)  WS (m/s)  WD (deg)  BP (mmHg)  \
# 0           7.88        1.52   99.15      0.22    171.49    1019.60
# 1           7.87        1.53   99.14      0.34    258.70    1019.28
# 2           7.09        1.53   99.14      0.27    267.53    1018.85
#
#    SO2 (ug/m3)  NO (ug/m3)  NO2 (ug/m3)  NOx (ppb)  NH3 (ug/m3)  CO (mg/m3)  \
# 0         4.11       10.42        33.75      26.29          NaN         NaN
# 1         4.49       10.16        31.26      24.76          NaN         NaN
# 2         3.15       10.17        28.38      23.23          NaN         NaN
#
#    Ozone (ug/m3)  Benzene (ug/m3)  Eth-Benzene (ug/m3)  MP-Xylene (ug/m3)  \
# ...

# %%
df2 = pd.read_csv('datasets/site_277.csv',index_col=0, parse_dates=['From Date','To Date'])
print(df2.shape)
# Out:
# (39230, 24)

# %%
df3 = pd.read_csv('datasets/site_297.csv',index_col=0, parse_dates=['From Date','To Date'])
df3.shape
# Out:
# (39140, 26)

# %%
df4 = pd.read_csv('datasets/site_5128.csv',index_col=0, parse_dates=['From Date','To Date'])
df4.shape
# Out:
# (23134, 25)

# %%
df5 = pd.read_csv('datasets/site_5460.csv',index_col=0, parse_dates=['From Date','To Date'])
df5.shape
# Out:
# (36838, 25)

# %%
df6 = pd.read_csv('datasets/site_5462.csv',index_col=0, parse_dates=['From Date','To Date'])
df6.shape
# Out:
# (6454, 25)

# %%
df1.set_index('From Date', inplace=True)
df2.set_index('From Date', inplace=True)
df3.set_index('From Date', inplace=True)
df4.set_index('From Date', inplace=True)
df5.set_index('From Date', inplace=True)
df6.set_index('From Date', inplace=True)

# %%
df1.rename(columns={'WD (deg)':'WD (degree)'},inplace=True)

# %%
df1.columns
# Out:
# Index(['To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'AT (degree C)',
#        'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)', 'BP (mmHg)',
#        'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)', 'NOx (ppb)', 'NH3 (ug/m3)',
#        'CO (mg/m3)', 'Ozone (ug/m3)', 'Benzene (ug/m3)', 'Eth-Benzene (ug/m3)',
#        'MP-Xylene (ug/m3)', 'O Xylene (ug/m3)', 'Toluene (ug/m3)', 'VWS (m/s)',
#        'TOT-RF (mm)'],
#       dtype='object')

# %%
df2.rename(columns={'WD (deg)':'WD (degree)'},inplace=True)

# %%
df2.columns
# Out:
# Index(['To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'Temp (degree C)',
#        'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)', 'BP (mmHg)',
#        'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)', 'NOx (ppb)', 'NH3 (ug/m3)',
#        'CO (mg/m3)', 'Ozone (ug/m3)', 'Benzene (ug/m3)', 'Eth-Benzene (ug/m3)',
#        'MP-Xylene (ug/m3)', 'O Xylene (ug/m3)', 'Toluene (ug/m3)', 'VWS (m/s)',
#        'TOT-RF (mm)'],
#       dtype='object')

# %%
df3=df3.rename(columns={'Eth-Benzene':'Eth-Benzene (ug/m3)'},inplace=False)

# %%
df3=df3.rename(columns={'MP-Xylene':'MP-Xylene (ug/m3)'},inplace=False)

# %%
df3=df3.rename(columns={'O Xylene':'O Xylene (ug/m3)'},inplace=False)

# %%
df3=df3.rename(columns={'WD (deg)':'WD (degree)'},inplace=False)

# %%
df3.columns
# Out:
# Index(['To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'Temp (degree C)',
#        'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)', 'BP (mmHg)',
#        'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)', 'NOx (ppb)', 'NH3 (ug/m3)',
#        'CO (mg/m3)', 'Ozone (ug/m3)', 'Benzene (ug/m3)', 'Eth-Benzene (ug/m3)',
#        'MP-Xylene (ug/m3)', 'O Xylene (ug/m3)', 'VWS (m/s)', 'NMHC (ug/m3)',
#        'THC ()', 'CH4 (ug/m3)', 'TOT-RF (mm)'],
#       dtype='object')

# %%
df4.rename(columns={
    'Eth-Benzene':'Eth-Benzene (ug/m3)',
    'MP-Xylene':'MP-Xylene (ug/m3)',
    'O Xylene':'O Xylene (ug/m3)'}
    ,inplace=True)

# %%
df4.columns
# Out:
# Index(['To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'AT (degree C)',
#        'Temp (degree C)', 'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)',
#        'BP (mmHg)', 'RF (mm)', 'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)',
#        'NOx (ppb)', 'CO (mg/m3)', 'Ozone (ug/m3)', 'Benzene (ug/m3)',
#        'Eth-Benzene (ug/m3)', 'MP-Xylene (ug/m3)', 'O Xylene (ug/m3)',
#        'Toluene (ug/m3)', 'VWS (m/s)', 'TOT-RF (mm)'],
#       dtype='object')

# %%
df5.columns
# Out:
# Index(['To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'AT (degree C)',
#        'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)', 'BP (mmHg)',
#        'RF (mm)', 'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)', 'NOx (ppb)',
#        'NH3 (ug/m3)', 'CO (mg/m3)', 'Ozone (ug/m3)', 'Benzene (ug/m3)',
#        'Eth-Benzene (ug/m3)', 'MP-Xylene (ug/m3)', 'O Xylene (ug/m3)',
#        'Toluene (ug/m3)', 'Xylene (ug/m3)', 'TOT-RF (mm)'],
#       dtype='object')

# %%
df6.columns
# Out:
# Index(['To Date', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'AT (degree C)',
#        'SR (W/mt2)', 'RH (%)', 'WS (m/s)', 'WD (degree)', 'BP (mmHg)',
#        'RF (mm)', 'SO2 (ug/m3)', 'NO (ug/m3)', 'NO2 (ug/m3)', 'NOx (ppb)',
#        'NH3 (ug/m3)', 'CO (mg/m3)', 'Ozone (ug/m3)', 'Benzene (ug/m3)',
#        'Eth-Benzene (ug/m3)', 'MP-Xylene (ug/m3)', 'O Xylene (ug/m3)',
#        'Toluene (ug/m3)', 'Xylene (ug/m3)', 'TOT-RF (mm)'],
#       dtype='object')

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['PM2.5 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['PM2.5 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['PM2.5 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['PM2.5 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['PM2.5 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['PM2.5 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['PM10 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['PM10 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['PM10 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['PM10 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['PM10 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['PM10 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(25,20), squeeze=False)    
df1['AT (degree C)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df4['AT (degree C)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df5['AT (degree C)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df6['AT (degree C)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['SR (W/mt2)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['SR (W/mt2)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['SR (W/mt2)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['SR (W/mt2)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['SR (W/mt2)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['SR (W/mt2)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['RH (%)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['RH (%)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['RH (%)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['RH (%)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['RH (%)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['RH (%)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['WS (m/s)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['WS (m/s)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['WS (m/s)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['WS (m/s)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['WS (m/s)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['WS (m/s)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['WD (degree)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['WD (degree)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['WD (degree)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['WD (degree)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['WD (degree)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['WD (degree)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['BP (mmHg)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['BP (mmHg)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['BP (mmHg)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['BP (mmHg)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['BP (mmHg)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['BP (mmHg)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['SO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['SO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['SO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['SO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['SO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['SO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['NO (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['NO (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['NO (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['NO (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['NO (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['NO (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['NO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['NO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['NO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['NO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['NO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['NO2 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['NOx (ppb)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['NOx (ppb)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['NOx (ppb)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['NOx (ppb)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['NOx (ppb)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['NOx (ppb)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['NH3 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['NH3 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['NH3 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df5['NH3 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df6['NH3 (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['CO (mg/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['CO (mg/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['CO (mg/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['CO (mg/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['CO (mg/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['CO (mg/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['Ozone (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['Ozone (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['Ozone (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['Ozone (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['Ozone (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['Ozone (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['Eth-Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['Eth-Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['Eth-Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['Eth-Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['Eth-Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['Eth-Benzene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['MP-Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['MP-Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['MP-Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['MP-Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['MP-Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['MP-Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['O Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['O Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['O Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['O Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['O Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['O Xylene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['Toluene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['Toluene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df4['Toluene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df5['Toluene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df6['Toluene (ug/m3)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
df3.columns.tolist()
# Out:
# ['To Date',
#  'PM2.5 (ug/m3)',
#  'PM10 (ug/m3)',
#  'Temp (degree C)',
#  'SR (W/mt2)',
#  'RH (%)',
#  'WS (m/s)',
#  'WD (degree)',
#  'BP (mmHg)',
#  'SO2 (ug/m3)',
#  'NO (ug/m3)',
#  'NO2 (ug/m3)',
#  'NOx (ppb)',
#  'NH3 (ug/m3)',
#  'CO (mg/m3)',
#  'Ozone (ug/m3)',
#  'Benzene (ug/m3)',
#  'Eth-Benzene (ug/m3)',
#  'MP-Xylene (ug/m3)',
#  'O Xylene (ug/m3)',
#  'VWS (m/s)',
#  'NMHC (ug/m3)',
#  'THC ()',
#  'CH4 (ug/m3)',
#  'TOT-RF (mm)']

# %%
fig, ax = plt.subplots( figsize=(10,5), squeeze=False)
df4['VWS (m/s)'].resample('M').sum().plot(kind='area',stacked='False')
# Out:
# <AxesSubplot: xlabel='From Date'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(25,20), squeeze=False)
df1['TOT-RF (mm)'].resample('M').sum().plot(kind='area', ax=ax[0,0])
df2['TOT-RF (mm)'].resample('M').sum().plot(kind='area', ax=ax[0,1])
df3['TOT-RF (mm)'].resample('M').sum().plot(kind='area', ax=ax[1,0])
df4['TOT-RF (mm)'].resample('M').sum().plot(kind='area', ax=ax[1,1])
df5['TOT-RF (mm)'].resample('M').sum().plot(kind='area', ax=ax[2,0])
df6['TOT-RF (mm)'].resample('M').sum().plot(kind='area', ax=ax[2,1])
# Out:
# <AxesSubplot: xlabel='From Date'>
